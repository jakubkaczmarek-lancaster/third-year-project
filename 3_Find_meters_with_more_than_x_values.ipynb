# %% [markdown]
# <a href="https://colab.research.google.com/github/jakubkaczmarek-lancaster/third-year-project/blob/main/3_Find_meters_with_more_than_x_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import glob

# %%
# The output of this was
fields = ['reading']
both = ['reading', 'name']
path = "/content/gdrive/My Drive/data/Synetica/meters_2019/*.csv"
for fname in glob.glob(path):
   df=pd.read_csv(fname, usecols=both)
   unique_readings=list(df[fields].nunique())
   useful = [i for i in unique_readings if i >= 1]
   if useful:
    print(df['name'][0], useful[0])
# Out:
# AP001-L01_M1 6
# AP001-L01_M2 5
# AP001-L01_M3 1
# AP001-L01_M4 1
# AP001-L01_M5 16
# AP001-L01_M6 14
# AP001-L01_M9R52 50031
# AP010-L01_M1 473
# AP010-L01_M2 25
# AP010-L01_M3 132
# AP010-L01_M4 26
# AP010-L01_M5 4
# AP011-L01_M1 28
# AP011-L01_M2 16
# AP011-L01_M3 1
# AP011-L01_M4 434
# AP057-L01_M1 38
# AP057-L01_M2 3
# AP057-L01_M9R52 49669
# AP080-L01_M1 3
# AP080-L01_M10R52 43483
# AP080-L01_M2 32
# AP080-L01_M3 8
# AP080-L01_M4 2
# AP080-L01_M5 1
# AP080-L01_M9R52 49916
# AP081-L01_M1 394
# AP081-L01_M2 8
# AP081-L01_M3 41
# AP081-L01_M4 1
# AP081-L01_M9R52 50021
# MC003-L02_M10R52 13924
# MC003-L02_M11R52 5919
# MC003-L02_M9R52 7267
# MC010-L01_M1 15
# MC010-L01_M10R52 50018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-88b77778b969> in <module>()
#       3 path = "/content/gdrive/My Drive/data/Synetica/meters_2019/*.csv"
# ...

# %%
fields = ['reading']
both = ['reading', 'name']
path = "/content/gdrive/My Drive/data/Synetica/meters_2019/*.csv"
for fname in glob.glob(path):
   df=pd.read_csv(fname, usecols=both)
   unique_readings=list(df[fields].nunique())
   useful = [i for i in unique_readings if i >= 1000]
   if useful:
    print(df['name'][0], useful[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17199977442a> in <module>()
#       2 both = ['reading', 'name']
#       3 path = "/content/gdrive/My Drive/data/Synetica/meters_2019/*.csv"
# ----> 4 for fname in glob.glob(path):
#       5    df=pd.read_csv(fname, usecols=both)
#       6    unique_readings=list(df[fields].nunique())
#
# NameError: name 'glob' is not defined

# %%
columns = ['timestamp', 'reading']

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from statsmodels.graphics.tsaplots import plot_acf

green = sns.color_palette("deep", 8)[2]
blue = sns.color_palette("deep", 8)[0]

# Loading the dataset
df_meter = pd.read_csv('/content/gdrive/My Drive/data/Synetica/meters_2019/MC204-L03_M9R16.csv', usecols=columns)

#Cleaning the dates column
df_meter['timestamp'] = pd.to_datetime(df_meter['timestamp'])
df_meter = df_meter.sort_values(by= 'timestamp')

#Plotting the raw data
fig = plt.figure(figsize=(30,8))
ax1 = fig.add_subplot(121)
#                                                                                   add .iloc[275:1000] after df_meter for smaller sample
plt.plot(df_meter.iloc[275:1000]["timestamp"],df_meter.iloc[275:1000]["reading"], color=green)
plt.title("Meter Data Time Series",fontsize=15)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Reading (kWh)",fontsize=15)
# Out:
# Text(0, 0.5, 'Reading (kWh)')

# %%
df_meter = pd.read_csv('/content/gdrive/My Drive/data/Synetica/meters_2019/MC204-L03_M9R16.csv')
df_meter['reading'].head().diff()
# Out:
# 0      NaN
# 1   -10.40
# 2    -0.48
# 3     4.00
# 4     0.16
# Name: reading, dtype: float64

# %%
columns = ['timestamp', 'reading']


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from statsmodels.graphics.tsaplots import plot_acf

green = sns.color_palette("deep", 8)[2]
blue = sns.color_palette("deep", 8)[0]

# Loading the dataset
df_meter = pd.read_csv('/content/gdrive/My Drive/data/Synetica/meters_2019/MC208-L01_M9R52.csv', usecols=columns)


#Cleaning the dates column
df_meter['timestamp'] = pd.to_datetime(df_meter['timestamp'])
df_meter = df_meter.sort_values(by= 'timestamp')
df_meter['reading'] = df_meter['reading'].diff()

#Plotting the raw data
fig = plt.figure(figsize=(30,8))
ax1 = fig.add_subplot(121)
#                                                                                   add .iloc[275:1000] after df_meter for smaller sample
plt.plot(df_meter["timestamp"],df_meter["reading"], color=green)
plt.title("Meter Data Time Series",fontsize=15)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Reading (kWh)",fontsize=15)
# Out:
# Text(0, 0.5, 'Reading (kWh)')

# %%
columns = ['timestamp', 'reading']


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from statsmodels.graphics.tsaplots import plot_acf

green = sns.color_palette("deep", 8)[2]
blue = sns.color_palette("deep", 8)[0]

# Loading the dataset
df_meter = pd.read_csv('/content/gdrive/My Drive/data/Synetica/meters_2018/MC208-L01_M9R52.csv', usecols=columns)


#Cleaning the dates column
df_meter['timestamp'] = pd.to_datetime(df_meter['timestamp'])
df_meter = df_meter.sort_values(by= 'timestamp')
df_meter['reading'] = df_meter['reading'].diff()

#Plotting the raw data
fig = plt.figure(figsize=(30,8))
ax1 = fig.add_subplot(121)
#                                                                                   add .iloc[275:1000] after df_meter for smaller sample
plt.plot(df_meter["timestamp"],df_meter["reading"], color=green)
plt.title("Meter Data Time Series",fontsize=15)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Current (A)",fontsize=15)
# Out:
# Text(0, 0.5, 'Current (A)')

# %%
df_meter.head()
# Out:
#             timestamp  reading
# 0 2019-01-01 00:30:00  95440.5
# 1 2019-01-01 01:10:00  95445.2
# 2 2019-01-01 01:50:00  95449.5
# 3 2019-01-01 02:30:00  95454.3
# 4 2019-01-01 03:10:00  95458.8

# %%
df_meter.set_index('timestamp').sort_index().diff().plot()
